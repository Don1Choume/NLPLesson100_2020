# %% [markdown]
# # 第1章: 準備運動

# %% [markdown]
# 00. 文字列の逆順
# 文字列”stressed”の文字を逆に（末尾から先頭に向かって）並べた文字列を得よ．

# %%
stressed = 'stressed'
stressed[::-1]
# Out:
# 'desserts'

# %% [markdown]
# 01. 「パタトクカシーー」
# 「パタトクカシーー」という文字列の1,3,5,7文字目を取り出して連結した文字列を得よ．

# %%
patato = 'パタトクカシーー'
patato[0::2]
# Out:
# 'パトカー'

# %% [markdown]
# 02. 「パトカー」＋「タクシー」＝「パタトクカシーー」
# 「パトカー」＋「タクシー」の文字を先頭から交互に連結して文字列「パタトクカシーー」を得よ．

# %%
pato = 'パトカー'
taxi = 'タクシー'
''.join([p+t for p, t in zip(pato, taxi)])
# Out:
# 'パタトクカシーー'

# %% [markdown]
# 03. 円周率
# “Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics.”という文を単語に分解し，各単語の（アルファベットの）文字数を先頭から出現順に並べたリストを作成せよ．

# %%
pi_txt = 'Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics.'
list(map(len, pi_txt.replace(',', '').replace('.', '').split(' ')))
# Out:
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9]

# %% [markdown]
# 04. 元素記号
# “Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can.”という文を単語に分解し，1, 5, 6, 7, 8, 9, 15, 16, 19番目の単語は先頭の1文字，それ以外の単語は先頭の2文字を取り出し，取り出した文字列から単語の位置（先頭から何番目の単語か）への連想配列（辞書型もしくはマップ型）を作成せよ．

# %%
atm_txt = 'Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can.'
single_idx = [1, 5, 6, 7, 8, 9, 15, 16, 19]
pre_lst = atm_txt.replace(',', '').replace('.', '').split(' ')
{chr[:(1 if i+1 in single_idx else 2)]: i+1 for i, chr in enumerate(pre_lst)}
# Out:
# {'Al': 13,
#  'Ar': 18,
#  'B': 5,
#  'Be': 4,
#  'C': 6,
#  'Ca': 20,
#  'Cl': 17,
#  'F': 9,
#  'H': 1,
#  'He': 2,
#  'K': 19,
#  'Li': 3,
#  'Mi': 12,
#  'N': 7,
#  'Na': 11,
#  'Ne': 10,
#  'O': 8,
#  'P': 15,
#  'S': 16,
#  'Si': 14}

# %% [markdown]
# 05. n-gram
# 与えられたシーケンス（文字列やリストなど）からn-gramを作る関数を作成せよ．この関数を用い，”I am an NLPer”という文から単語bi-gram，文字bi-gramを得よ．

# %%
def n_gram(text, n, mode='char'):
  txt_lst = text.replace(',', '').replace('.', '').split(' ')
  if mode=='char':
    result = [t_[i:i+n] for t_ in txt_lst for i in range(max(len(t_)-1, 1))]
  else:
    result = [txt_lst[i:i+n] for i in range(max(len(txt_lst)-1, 1))]
  return result

targ = 'I am an NLPer'
print('char_bi: ', n_gram(targ, 2, mode='char'))
print('word_bi: ', n_gram(targ, 2, mode='word'))
# Out:
# char_bi:  ['I', 'am', 'an', 'NL', 'LP', 'Pe', 'er']
# word_bi:  [['I', 'am'], ['am', 'an'], ['an', 'NLPer']]

# %%
# 納得いかないがスペースもn-gramの要素に含む場合
def n_gram(text, n, mode='char'):
  if mode!='char':
    text = text.replace(',', '').replace('.', '').split(' ')
  return [text[i:i+n] for i in range(max(len(text)-1, 1))]

targ = 'I am an NLPer'
print('char_bi: ', n_gram(targ, 2, mode='char'))
print('word_bi: ', n_gram(targ, 2, mode='word'))
# Out:
# char_bi:  ['I ', ' a', 'am', 'm ', ' a', 'an', 'n ', ' N', 'NL', 'LP', 'Pe', 'er']
# word_bi:  [['I', 'am'], ['am', 'an'], ['an', 'NLPer']]

# %% [markdown]
# 06. 集合
# “paraparaparadise”と”paragraph”に含まれる文字bi-gramの集合を，それぞれ, XとYとして求め，XとYの和集合，積集合，差集合を求めよ．さらに，’se’というbi-gramがXおよびYに含まれるかどうかを調べよ．

# %%
X = n_gram('paraparaparadise', 2, mode='char')
Y = n_gram('paragraph', 2, mode='char')

print('sum: ', set(X)|set(Y))
print('product: ', set(X)&set(Y))
print('sub: ', set(X)-set(Y))
print('"se" in X: ', 'se' in X)
print('"se" in Y: ', 'se' in Y)
# Out:
# sum:  {'se', 'ar', 'ad', 'ra', 'ph', 'pa', 'is', 'di', 'ag', 'gr', 'ap'}
# product:  {'ra', 'ar', 'pa', 'ap'}
# sub:  {'se', 'is', 'di', 'ad'}
# "se" in X:  True
# "se" in Y:  False

# %% [markdown]
# 07. テンプレートによる文生成
# 引数x, y, zを受け取り「x時のyはz」という文字列を返す関数を実装せよ．さらに，x=12, y=”気温”, z=22.4として，実行結果を確認せよ．

# %%
def create_str(x, y, z):
  return '{0}時の{1}は{2}'.format(x, y, z)

create_str(12, '気温', 22.4)
# Out:
# '12時の気温は22.4'

# %% [markdown]
# 08. 暗号文
# 与えられた文字列の各文字を，以下の仕様で変換する関数cipherを実装せよ．
# * 英小文字ならば(219 - 文字コード)の文字に置換
# * その他の文字はそのまま出力
# この関数を用い，英語のメッセージを暗号化・復号化せよ

# %%
def cipher(string):
  return ''.join(map(lambda s: chr(219-ord(s)) if 97 <= ord(s) <= 122 else s, string))

cipher('a to z and A TO Z')
# Out:
# 'z gl a zmw A TO Z'

# %% [markdown]
# 09. Typoglycemia
# スペースで区切られた単語列に対して，各単語の先頭と末尾の文字は残し，それ以外の文字の順序をランダムに並び替えるプログラムを作成せよ．ただし，長さが４以下の単語は並び替えないこととする．適当な英語の文（例えば”I couldn’t believe that I could actually understand what I was reading : the phenomenal power of the human mind .”）を与え，その実行結果を確認せよ．

# %%
import random

def word_shuffle(word):
  return word if len(word)<=4 else word[0]+''.join(random.sample(word[1:-1], len(word)-2))+word[-1]

def sent_shuffle(sent):
  return ' '.join([word_shuffle(w) for w in sent.split(' ')])

sent_shuffle('I couldn’t believe that I could actually understand what I was reading : the phenomenal power of the human mind .')
# Out:
# 'I cduonl’t bielvee that I cloud actulaly unernatdsd what I was raneidg : the poamenenhl pwoer of the huamn mind .'
